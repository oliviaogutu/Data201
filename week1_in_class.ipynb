# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/Data201/blob/main/week1_in_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')

# %%
print(1+1)

# %% [markdown]
# # Title
# ## subtitle
#
# 1. first
# 2. second
# 3. third
#
# - [X] list  1
# - [ ] list 2

# %%
x=1
y=2

# %%
z=x+y

# %%
w=x**2
print(w)

# %%
a=x+1
